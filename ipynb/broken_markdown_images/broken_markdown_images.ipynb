# %% [markdown]
# Base64 images work via `![](...<img>`
#
# ![](data:image/png;base64,...)

# %% [markdown]
# Markdown with relative path `![](visualization.png)`
#
# ![](visualization.png)

# %% [markdown]
# Markdown with relative path and raw option `![](visualization.png?raw=true)`
#
# ![](visualization.png?raw=true)
